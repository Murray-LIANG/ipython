# %%
import pywbemReq

c = pywbemReq.WBEMConnection('https://10.245.101.39:5989',
                             ('Local/admin', 'Password123!'), default_namespace='root/emc/smis')

# c = pywbemReq.WBEMConnection('https://10.103.207.9:5989',
#                              ('Local/admin', 'Password123!'), default_namespace='root/emc/smis')

host = [h for h in c.EnumerateInstances('EMC_VNXe_LunMaskingProtocolControllerLeaf') if h['Name'] =='Host_9'][0]

print(host.tomof())

print(host.path)
# Out:
# /usr/local/lib/python2.7/dist-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# instance of EMC_VNXe_LunMaskingProtocolControllerLeaf {
# 	RequestedState = 12;
# 	ElementName = "win10-liangr";
# 	Name = "Host_9";
# 	TransitioningToState = 12;
# 	EMCAdapterRole = "FRONT_END";
# 	HealthState = 10;
# 	NameFormat = 1;
# 	SystemName = "FNM00150600267";
# 	DeviceID = "Host_9";
# 	CreationClassName = "EMC_VNXe_LunMaskingProtocolControllerLeaf";
# 	EnabledState = 5;
# 	SystemCreationClassName = "EMC_VNXe_StorageSystemLeaf";
# };
#
# root/emc/smis:EMC_VNXe_LunMaskingProtocolControllerLeaf.CreationClassName="EMC_VNXe_LunMaskingProtocolControllerLeaf",SystemName="FNM00150600267",DeviceID="Host_9",SystemCreationClassName="EMC_VNXe_StorageSystemLeaf"

# %%
import time

times = []

for _ in range(1): 
    start_t = time.time()

    try:
        volume_paths = c.AssociatorNames(host.path, resultClass='CIM_StorageVolume')
    except Exception:
        times.append(None)
    else:   
        elapsed_t = time.time() - start_t
        times.append(elapsed_t)
# Out:
# /usr/local/lib/python2.7/dist-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
print(len(volume_paths))

for p in volume_paths:
    print(p)
# Out:
# 400
# //10.245.101.39/root/emc/smis:EMC_VNXe_StorageVolumeLeaf.CreationClassName="EMC_VNXe_StorageVolumeLeaf",SystemName="FNM00150600267",DeviceID="sv_271",SystemCreationClassName="EMC_VNXe_StorageSystemLeaf"
# //10.245.101.39/root/emc/smis:EMC_VNXe_StorageVolumeLeaf.CreationClassName="EMC_VNXe_StorageVolumeLeaf",SystemName="FNM00150600267",DeviceID="sv_272",SystemCreationClassName="EMC_VNXe_StorageSystemLeaf"
# //10.245.101.39/root/emc/smis:EMC_VNXe_StorageVolumeLeaf.CreationClassName="EMC_VNXe_StorageVolumeLeaf",SystemName="FNM00150600267",DeviceID="sv_273",SystemCreationClassName="EMC_VNXe_StorageSystemLeaf"
# //10.245.101.39/root/emc/smis:EMC_VNXe_StorageVolumeLeaf.CreationClassName="EMC_VNXe_StorageVolumeLeaf",SystemName="FNM00150600267",DeviceID="sv_274",SystemCreationClassName="EMC_VNXe_StorageSystemLeaf"
# ...

# %%
times_valid = filter(None, times)
print(times_valid)
print(len(times_valid))

print(sum(times_valid)/len(times_valid))
# Out:
# [30.351855993270874]
# 1
# 30.3518559933

# %%
# Out:
# 99

# %%
volume_paths = c.AssociatorNames(host.path, resultClass='CIM_StorageVolume')
# Out:
# /usr/local/lib/python2.7/dist-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
print(len(volume_paths))
# Out:
# 200
